# %%
# !pip install transformers[torch]
# !pip install datasets
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu118)
# Collecting accelerate>=0.20.3 (from transformers[torch])
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
import pandas as pd
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, TrainerCallback
import string
import numpy as np
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/ECE1786/Project/CSVs'
# Out:
# /content/drive/.shortcut-targets-by-id/1dzrXydfa8tV9U7malP1p3mQtrDhnia76/Project/CSVs

# %%
# Read CSV as Pandas DataFrame
data_df = pd.read_csv("trainingdata_gpt2.csv", header=None, names=["sentence", "label"])

# %%
# Remove trailing punctuation from masked token labels

def remove_punctuation(text):
  return text.translate(str.maketrans('', '', string.punctuation))

data_df['label'] = data_df['label'].apply(remove_punctuation)

# %%
data_df
# Out:
#                                                 sentence     label
# 0              MEMORANDUM FOR: Inspector General, [MASK]       CIA
# 1      document that would [MASK] CIA and the IC impr...      help
# 2      document that would help [MASK] and the IC imp...       CIA
# 3      sets a precedent for demands that [MASK] CIA also       the
# 4      sets a precedent for demands that the [MASK] also       CIA
# ...                                                  ...       ...
# 15942  James Locher, Victory on [MASK] Potomac: The G...       the
# 15943  James Locher, Victory on the Potomac: The Gold...  Pentagon
# 15944  8. For a history of the DCI’s authority over t...       see
# 15945  8. For a history of the DCI’s authority over t...       CIA
# 15946  [MASK] to advise the Department of Defense on ...  Rumsfeld
#
# [15947 rows x 2 columns]

# %%
model_name = "gpt2" # Just change this to try out different models
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/ECE1786/Project/Tokenizer Files/gpt2_tokenizer") #load just the tokenizer
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Add masked token labels to vocabulary (cannot be split into multiple tokens)
# only needs to be run when trying out a new model or training set

# for i, word in enumerate(data_df["label"].values):
#   if word not in tokenizer.vocab:
#     tokenizer.add_tokens(word)

# %%
#tokenizer.save_pretrained("/content/drive/MyDrive/ECE1786/Project/Tokenizer Files/gpt2_tokenizer") #save the tokenizer

# %%
# tokenizer = AutoTokenizer.from_pretrained("drive/MyDrive/Project/Tokenizer Files/gpt2_tokenizer")

# %%
# data_df = data_df[:20] # For testing purposes

# Convert Pandas DataFrame to HuggingFace Dataset
full_dataset = Dataset.from_pandas(data_df)
full_dataset = full_dataset.shuffle(seed=42)
# Split dataset into train-test-validation sets
train_testvalid = full_dataset.train_test_split(test_size =0.3)
# Split the 10% test + valid in half test, half valid
test_valid = train_testvalid['test'].train_test_split(test_size = 0.65)
# gather everyone if you want to have a single DatasetDict
data_ds = DatasetDict({
    'train': train_testvalid['train'],
    'test': test_valid['test'],
    'val': test_valid['train']})
data_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 11162
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 3111
#     })
#     val: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 1674
#     })
# })

# %%
# Apply tokenizer

def tokenize_function(batch):
  # Tokenize sentences
  encoded_batch = tokenizer(batch["sentence"], padding="max_length", truncation=True, max_length=64)
  # Create label for each sentence: -100 for unmasked token, actual ID for masked token (list)
  tokenized_sentences = encoded_batch.input_ids.copy()
  encoded_labels = []
  for i, sent in enumerate(tokenized_sentences):
    encoded_labels += [[-100]*len(sent)]
    for j, token_id in enumerate(sent):
      if token_id == tokenizer.mask_token_id:
        if tokenizer.tokenize(batch["label"][i]) == []:
          label = " "
        else:
          label = tokenizer.tokenize(batch["label"][i])[0]
        encoded_labels[-1][j] = tokenizer.convert_tokens_to_ids(label)
        break # Can break as only one mask per sentence
  encoded_batch["label"] = encoded_labels
  return encoded_batch

tokenized_data_ds = data_ds.map(tokenize_function, batched= True)
# Out:
# Map:   0%|          | 0/11162 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3111 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1674 [00:00<?, ? examples/s]

# %%
tokenized_data_ds["train"]["label"][0] # All -100 except 1
# Out:
# [-100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  1525,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100]

# %%
eval_len = tokenized_data_ds['val'].num_rows

# %%
def compute_metrics(eval_preds):
  logits, labels = eval_preds
  # Get ground truths of masked tokens and predicted tokens
  masked_tokens_gts = []
  masked_tokens_inds = []
  for label in labels:
    for i in range(len(label)):
      if label[i] != -100:
        masked_tokens_inds += [i]
        masked_tokens_gts += [label[i]]*10 #multiply by k = 10 to accomodate top k predictions
        break
  # Get predicted masked token (index = token_id)
  predicted_sent = torch.topk(torch.tensor(logits), 10, dim=2).indices #do topk with k = 10
  predicted_masked_tokens = []
  for i, ind in enumerate(masked_tokens_inds):
    predicted_masked_tokens += predicted_sent[i][ind] #get whole flattened list of topk predictions
  # Compute accuracy
  accuracy = 10*sum(masked_tokens_gts == np.array(predicted_masked_tokens))/len(masked_tokens_gts) #multipy by k to compensate for flattening
  return {'accuracy': accuracy}

# %%
# Initialize model and training arguments

initial_model = AutoModelForCausalLM.from_pretrained(model_name)
initial_model.config.vocab_size = tokenizer.vocab_size
initial_model.resize_token_embeddings(len(tokenizer))
# model.config.pad_token_id = model.config.eos_token_id

training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/ECE1786/Project/Models/GPT",
    overwrite_output_dir=True,
    evaluation_strategy = "steps",
    per_device_eval_batch_size= 100,
    eval_steps = 1/20, # Can just be a ratio less than 1 of the total training steps
    logging_steps = 1/20,
    save_total_limit=1,
    save_strategy="epoch",
    per_device_train_batch_size = 32,
    learning_rate = 5e-4,
    eval_accumulation_steps = 2 #this is the parameter that prevents GPU memory overflow (unload eval results to CPU memory)
)
class EvalCallback(TrainerCallback):
    def on_evaluate(self, args, state, control, logs=None, **kwargs):
      kwargs['model'].eval()
      pass
    def on_log(self, args, state, control, logs=None, **kwargs):
      kwargs['model'].train()
      pass
ee = EvalCallback()
trainer = Trainer(
    model = initial_model,
    args = training_args,
    train_dataset=tokenized_data_ds["train"],
    eval_dataset=tokenized_data_ds["val"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks = [ee]
)

# Train model
# trainer.train()
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# trainer.save_model("/content/drive/MyDrive/ECE1786/Project/Models/GPT")

# %%
#test a saved model from model_dir, with training arguments from training set to RAM doesn't overflow
#with known maxmimum val batch size to prevent RAM overflow
def test(model_dir, training_args, tokenized_data_ds, val_size):
  model = AutoModelForCausalLM.from_pretrained(model_dir)
  model.eval()

  tester = Trainer(
    model = model,
    args = training_args,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
  )
  accuracy = 0.0
  total_samples = 0
  test_set = tokenized_data_ds['test']
  n = test_set.num_rows
  while n > 0:
    print(n)
    if n > val_size:
      total_samples += val_size
      test_sets = test_set.train_test_split(test_size = val_size/n)
      n = test_sets['train'].num_rows
      accuracy += val_size*tester.evaluate(test_sets['test'])['eval_accuracy']
      test_set = test_sets['train']
    else:
      total_samples += test_set.num_rows
      accuracy += test_set.num_rows*tester.evaluate(test_set)['eval_accuracy']
      n = 0
  return "accuracy: "+str(accuracy/total_samples)
# print(test("/content/drive/MyDrive/ECE1786/Project/Models/GPT", training_args, tokenized_data_ds, 1674))

# %%
def get_samples(model_dir, tokenized_data_ds):
  model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path = model_dir)
  model.eval()

  for i in range(100):
    ids = torch.tensor([tokenized_data_ds['test']['input_ids'][i]])
    label_ids = tokenized_data_ds['test']['label'][i]
    mask_id = 0
    for j, id in enumerate(label_ids):
      if id != -100:
        label = tokenizer.convert_ids_to_tokens(id)
        mask_id = j
    trimmed_ids_nonzero_idx = ids[0].clone().detach().nonzero() #get rid of pad tokens for demonstration purposes
    trimmed_ids = ids[0].clone().detach()[trimmed_ids_nonzero_idx]
    input_sentence = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(trimmed_ids))
    output = model(ids)
    logits = output.logits[0][mask_id]
    probs, ids = torch.sort(torch.softmax(logits, dim = 0), dim = 0, descending = True)

    print("Input Sentence: "+ input_sentence)
    print("Correct Label: "+label)
    print("Probabilities: "+str(probs[:10].detach().numpy()))
    print("Top 10 Guesses: "+str(tokenizer.convert_ids_to_tokens(ids[:10])))
    print("\n")
  return

# %%
get_samples("/content/drive/MyDrive/ECE1786/Project/Models/GPT", tokenized_data_ds)
# Out:
# Input Sentence: Predator,” July 11, 2001. On Rice’s intervention, [MASK] Condoleezza Rice meeting (Feb. 7, 2004).[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: see
# Probabilities: [9.5461613e-01 1.1518328e-02 6.4098448e-03 4.6375454e-03 2.2110285e-03
#  1.8114971e-03 1.4239107e-03 9.8433194e-04 7.5563532e-04 6.9339998e-04]
# Top 10 Guesses: ['see', 'See', 'FBI', 'and', 'the', 'also', 'Richard', 'but', 'Inside', 'wrote']
#
#
# Input Sentence: Intelligence report, [MASK] of Hambali, Sept. 12, 2003. In an assessment of KSM’s reporting, the CIA con-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: interrogation
# Probabilities: [0.5755051  0.13048992 0.0790142  0.050164   0.04953224 0.03713523
#  0.01266087 0.0115825  0.00411337 0.00392461]
# Top 10 Guesses: ['interrogation', 'Usama', 'Khallad', 'CTC', 'Binalshibh', 'Bin', 'Ramzi', 'Abu', 'Mohamed', 'Al']
#
#
# Input Sentence: [MASK] Hazmi had arrived in Falls Church, Virginia.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: and
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: Attacking the Usama Bin [MASK] Problem,” Nov. 24, 1998. On the MON, see Randy Moss interview (Feb. 6, 2004);[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ladin
# Probabilities: [0.07130998 0.05885959 0.0474499  0.03723828 0.0364763  0.03078315
#  0.0300505  0.02685948 0.02635467 0.02361592]
# Top 10 Guesses: ['left', 'and', 'Mihdhar', 'Binalshibh', 'Berger', 'Rice', 'Ladin', 'Abu', 'al', 'Jarrah']
#
#
# Input Sentence: ers of Thumairy. [MASK] electronic communication, “Fahad Althumairy,” Oct. 25, 2002.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.59404683 0.04099605 0.03061949 0.0209227  0.01699322 0.01585759
#  0.01145122 0.01015028 0.00982214 0.00861455]
# Top 10 Guesses: ['FBI', 'Al', 'The', 'See', 'CIA', 'For', 'Hazmi', 'FAA', 'Ali', 'Although']
#
#
# Input Sentence: possible associations between Emirati officials and Bin [MASK] Clarke later wrote[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ladin
# Probabilities: [0.23191409 0.15737846 0.13114417 0.0453447  0.03694398 0.0315997
#  0.0272564  0.02480752 0.02465655 0.02096874]
# Top 10 Guesses: ['Ladin', 'Bin', 'and', 'al', 'Binalshibh', 'Mihdhar', 'Abu', 'Laden', 'Khallad', 'Omar']
#
#
# Input Sentence: department designated [MASK] a state sponsor of terrorism in 1993, it put Bin[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Sudan
# Probabilities: [0.08312046 0.07498263 0.05523935 0.04661361 0.03025971 0.02959534
#  0.02329278 0.02273852 0.02158292 0.02069955]
# Top 10 Guesses: ['Hazmi', 'FBI', 'CIA', 'Hanjour', 'Mihdhar', 'Jarrah', 'Abdullah', 'al', 'CTC', 'FAA']
#
#
# Input Sentence: identity as well as [MASK] methods used to obtain [MASK] information. Moreover, [MASK] FBI agent also may have been absent[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: the
# Probabilities: [0.35512698 0.1123389  0.09362169 0.02390461 0.02315863 0.01329448
#  0.01039786 0.01012489 0.0096143  0.00928627]
# Top 10 Guesses: ['FBI', 'the', 'CIA', 'The', 'Richard', 'that', 'an', 'because', 'Thomas', 'within']
#
#
# Input Sentence: Weapons” (February 2001), “Taliban Holding Firm on Bin [MASK] for Now”[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ladin
# Probabilities: [0.07776687 0.05295971 0.05025029 0.04367248 0.04365979 0.04345401
#  0.03817805 0.03407183 0.02765059 0.0244714 ]
# Top 10 Guesses: ['Berger', 'Bin', 'Clarke', 'Rice', 'Binalshibh', 'CTC', 'Khallad', 'Usama', 'Abu', 'Omar']
#
#
# Input Sentence: With the Sudanese regime acting as intermediary, [MASK] Ladin himself met[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.38030037 0.02533344 0.02436607 0.02419805 0.02300478 0.02265166
#  0.02264122 0.02029213 0.01965579 0.01903383]
# Top 10 Guesses: ['Bin', 'the', 'Hazmi', 'Clarke', 'CTC', 'al', 'Abu', 'Binalshibh', 'Moussaoui', 'Usama']
#
#
# Input Sentence: who came [MASK] Hamburg [MASK] visit Shehhi noticed he no longer lived as comfort-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: to
# Probabilities: [0.11327361 0.07941519 0.03898741 0.03806899 0.03237681 0.03230898
#  0.02784355 0.02757606 0.02467442 0.02391691]
# Top 10 Guesses: ['to', 'Hazmi', 'Rice', 'Hanjour', 'Clarke', 'Binalshibh', 'Jarrah', 'Mihdhar', 'Berger', 'Ahmed']
#
#
# Input Sentence: andy [MASK] “upbraided Tenet so sharply .. that it led Tenet to walk out of a Principats[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Berger
# Probabilities: [0.12106445 0.10484729 0.05471555 0.05350364 0.03078239 0.02211939
#  0.02211725 0.02144468 0.02044442 0.015433  ]
# Top 10 Guesses: ['FBI', 'CIA', 'Thomas', 'Richard', 'and', 'Ali', 'Al', 'William', 'Rice', 'Condoleezza']
#
#
# Input Sentence: [MASK] interview 24, Intelligence (June 15, 2004).[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: NYPD
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: After the [MASK] recruits joined the 9/11 conspiracy, al Qaeda began giv-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hamburg
# Probabilities: [0.15956289 0.13359915 0.12624657 0.05718633 0.03234644 0.02822013
#  0.02641195 0.02088706 0.01772418 0.01729794]
# Top 10 Guesses: ['FBI', 'CIA', 'FAA', 'NYPD', 'Bin', 'CTC', 'Pentagon', 'DOD', 'Hazmi', 'Hamburg']
#
#
# Input Sentence: Hambali used [MASK] Ladin’s Afghan facilities as a training ground for JI[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.11282421 0.07948892 0.0658833  0.05379084 0.04387327 0.04115592
#  0.03739193 0.0365003  0.03511923 0.03311826]
# Top 10 Guesses: ['Mihdhar', 'Hanjour', 'Hazmi', 'Binalshibh', 'Abu', 'Jarrah', 'Khallad', 'Omar', 'Rice', 'Ahmed']
#
#
# Input Sentence: KSM sent an al [MASK] operative named Issa al Britani to visit Hambali in Malaysia. At the end of the visit, Issa pro-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Qaeda
# Probabilities: [0.141039   0.11528483 0.03310784 0.01759102 0.01633467 0.01487307
#  0.01331201 0.01258823 0.01188108 0.0115085 ]
# Top 10 Guesses: ['CIA', 'and', 'FBI', 'Qaeda', 'wrote', 'killing', 'or', 'The', 'to', 'for']
#
#
# Input Sentence: Similarly, Thumairy’s claim not to know Mohdar [MASK] is belied by Abdul-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Abdullah
# Probabilities: [0.03857381 0.03704425 0.03245407 0.02265343 0.02242424 0.02077903
#  0.020691   0.01823378 0.01806458 0.01751532]
# Top 10 Guesses: ['FBI', 'bin', 'CIA', 'Binalshibh', 'Al', 'and', 'Ali', 'Abu', 'Omar', 'Bin']
#
#
# Input Sentence: individual only later identified as [MASK] Binalshibh would remain undiscov-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ramzi
# Probabilities: [0.09568384 0.0869168  0.06309997 0.0515311  0.04555944 0.0304956
#  0.02783843 0.02147865 0.02130939 0.01730571]
# Top 10 Guesses: ['FBI', 'Ali', 'CIA', 'Hazmi', 'al', 'bin', 'Hanjour', 'the', 'an', 'Jarrah']
#
#
# Input Sentence: atives. [MASK] argues that al Qaeda wanted to send a message to the gov-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Binalshibh
# Probabilities: [0.10431416 0.09667231 0.06628511 0.05100511 0.04516333 0.04479049
#  0.02319368 0.0155428  0.015031   0.01457256]
# Top 10 Guesses: ['FBI', 'CIA', 'The', 'Richard', 'Ali', 'Al', 'For', 'Berger', 'Rice', 'Clarke']
#
#
# Input Sentence: with respect to its permanent and contract employees. Even as the [MASK] has increased its language services cadre,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.6149234  0.13912407 0.03981129 0.03500453 0.03355361 0.01128414
#  0.00939169 0.00701072 0.00629849 0.00412095]
# Top 10 Guesses: ['FBI', 'CIA', 'FAA', 'NYPD', 'Richard', 'William', 'also', 'former', 'al', 'DOD']
#
#
# Input Sentence: KSM and [MASK] Zubaydah each played key roles in facilitating travel for al[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Abu
# Probabilities: [0.27608564 0.10798003 0.10349991 0.0878646  0.04900257 0.04131027
#  0.03388064 0.03188725 0.02678501 0.02528583]
# Top 10 Guesses: ['Binalshibh', 'Mihdhar', 'Khallad', 'Abu', 'Bin', 'Hanjour', 'Ramzi', 'Hazmi', 'Shehhi', 'Ahmed']
#
#
# Input Sentence: mediary between the plotters and [MASK] Ladin. (In a meeting with U.S. officials[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.166631   0.12637345 0.03437642 0.03200975 0.02988686 0.01959773
#  0.01824594 0.01822436 0.01768756 0.01417753]
# Top 10 Guesses: ['CIA', 'Bin', 'Richard', 'FBI', 'Hazmi', 'Abu', 'Taliban', 'CTC', 'Mihdhar', 'al']
#
#
# Input Sentence: Camp David military plan to attack [MASK] Taliban and al Qaeda if [MASK] Taliban[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: the
# Probabilities: [0.13026458 0.10494732 0.09974498 0.04796367 0.03879093 0.03673919
#  0.03624845 0.01964707 0.01907357 0.01673431]
# Top 10 Guesses: ['Richard', 'William', 'CIA', 'Secretary', 'The', 'the', 'General', 'Berger', 'Thomas', 'and']
#
#
# Input Sentence: the port of entry. The names of at least three of the hijackers (Nawaf [MASK] Hazmi, Salem [MASK] Hazmi, and Khalid [MASK] Mih-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.31902438 0.14894895 0.0342669  0.03256194 0.03123109 0.02401578
#  0.01546508 0.01532528 0.01505257 0.01450097]
# Top 10 Guesses: ['al', 'FBI', 'bin', 'and', 'Ali', 'Hazmi', 'an', 'see', 'or', 'Hanjour']
#
#
# Input Sentence: [MASK] interview 12, Aviation (Mar. 10, 2004); [MASK] interview 14, Aviation (Mar. 11, 2004); [MASK] interview[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: NYPD
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: 102. [MASK] FAA regulations, Hijacked Aircraft, Order 7110.65M, para.10-2-6 (2001); David Bottiglia interview[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: See
# Probabilities: [0.15309273 0.11811972 0.08333529 0.07596761 0.06778003 0.06568926
#  0.05745347 0.05416311 0.04966125 0.0248016 ]
# Top 10 Guesses: ['CIA', 'Richard', 'FAA', 'Condoleezza', 'DOJ', 'FBI', 'DOD', 'Samuel', 'NYPD', 'William']
#
#
# Input Sentence: als are good reporters but are unlikely to capture [MASK] Ladin because of the risks involved, so there is a need to[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.25204742 0.04970514 0.04432594 0.03048117 0.02396687 0.02253166
#  0.02080471 0.01952038 0.01928571 0.01922095]
# Top 10 Guesses: ['Bin', 'CIA', 'the', 'The', 'Hazmi', 'Usama', 'al', 'Khallad', 'Abu', 'CTC']
#
#
# Input Sentence: ities in Somalia [MASK] Sudanese NIF Support, Apr. 30, 1997.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: and
# Probabilities: [0.24459803 0.16036656 0.07201589 0.04980771 0.03557463 0.02015604
#  0.01773049 0.01564913 0.01402674 0.01323024]
# Top 10 Guesses: ['bin', 'and', 'al', 'Hazmi', 'Bin', 'Al', 'Ali', 'or', 'Mihdhar', 'while']
#
#
# Input Sentence: and Moussaoui, [MASK] Qaeda was looking for another possible pilot candidate. A[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.11293758 0.04738584 0.03811033 0.03745915 0.03612215 0.03364279
#  0.03286381 0.0269122  0.02679703 0.02639672]
# Top 10 Guesses: ['and', 'Binalshibh', 'Rice', 'Jarrah', 'al', 'Hanjour', 'the', 'Hazmi', 'Berger', 'CIA']
#
#
# Input Sentence: dent. [MASK] memo, Feith to Rumsfeld, “Briefing Draft,” Sept. 20, 2001.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: DOD
# Probabilities: [0.07537047 0.07164676 0.06686484 0.06249316 0.06142347 0.04942399
#  0.03959708 0.03586983 0.02879394 0.02851805]
# Top 10 Guesses: ['The', 'Berger', 'Clarke', 'Rice', 'Richard', 'Condoleezza', 'CIA', 'Samuel', 'For', 'DOJ']
#
#
# Input Sentence: offensive” and [MASK] Bin Ladin could not be deterred. A wide-ranging discus-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: that
# Probabilities: [0.15211092 0.11344489 0.0561488  0.04132478 0.04115148 0.03845407
#  0.03629014 0.03044616 0.01785056 0.01538238]
# Top 10 Guesses: ['CIA', 'FBI', 'Bin', 'the', 'FAA', 'Richard', 'al', 'CTC', 'NYPD', 'Clarke']
#
#
# Input Sentence: 59. NSC memo, Kurtz to [MASK] roadmap for March 10 PC meeting, Mar. 8, 2000.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Berger
# Probabilities: [0.683429   0.09543376 0.02599972 0.02009351 0.01735018 0.0083571
#  0.00816934 0.00790969 0.00747055 0.00625177]
# Top 10 Guesses: ['Berger', 'Rice', 'Clarke', 'and', 'Hadley', 'Cressey', 'CIA', 'Condoleezza', 'for', 'Binalshibh']
#
#
# Input Sentence: more evidence came in. [MASK] Clarke worried that the CIA might be equiv-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Though
# Probabilities: [0.12987536 0.10667481 0.07241191 0.06981821 0.03731784 0.01307391
#  0.01253854 0.01241448 0.01149286 0.01132252]
# Top 10 Guesses: ['CIA', 'FBI', 'the', 'The', 'Richard', 'al', 'Ali', 'Thomas', 'an', 'When']
#
#
# Input Sentence: monds.2 There also have been claims that [MASK] Qaeda financed itself through[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.12489697 0.08160865 0.04422101 0.03915095 0.02968405 0.02592828
#  0.02471733 0.02372668 0.02308726 0.02214139]
# Top 10 Guesses: ['CIA', 'the', 'Bin', 'The', 'Hazmi', 'CTC', 'al', 'Clarke', 'Al', 'Richard']
#
#
# Input Sentence: thinking can be seen throughout the summer of 1999. See, e.g., CIA briefing materials, [MASK] UBL Update:“Must[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: CTC
# Probabilities: [0.06881481 0.0590923  0.05746172 0.05093814 0.04562593 0.045613
#  0.04267556 0.04072563 0.03777424 0.03641187]
# Top 10 Guesses: ['CIA', 'CTC', 'DOJ', 'FAA', 'Samuel', 'Condoleezza', 'Clarke', 'Berger', 'DOD', 'Binalshibh']
#
#
# Input Sentence: 147. For the instructions to civilians, see [MASK] interview 3, HQ (Jan. 15, 2004). For the officers at 5 WTC[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: NYPD
# Probabilities: [0.47155178 0.14457342 0.07576698 0.06472766 0.05129504 0.04292324
#  0.0306566  0.02832793 0.02268514 0.01170101]
# Top 10 Guesses: ['NYPD', 'FAA', 'DOD', 'Richard', 'William', 'DOJ', 'Samuel', 'Condoleezza', 'also', 'Thomas']
#
#
# Input Sentence: received from Nibras and Quso [MASK] Hazmi and Mihdhar. Intelligence reports, interrogations of Khallad, Aug. 8, 2003;[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: to
# Probabilities: [0.13643602 0.08308323 0.03666713 0.02908454 0.02906122 0.02367152
#  0.02360169 0.01661814 0.01250575 0.01221917]
# Top 10 Guesses: ['to', 'and', 'for', 'Rice', 'CIA', 'Berger', 'FBI', 'the', 'Clarke', 'with']
#
#
# Input Sentence: 11, 2001. [MASK] did not circulate written rules of engagement until sometime after 1:00 pM. See [MASK] memo,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: DOD
# Probabilities: [0.17425483 0.09824175 0.05912877 0.05602245 0.04171894 0.04026672
#  0.03711663 0.03633523 0.03619248 0.03524161]
# Top 10 Guesses: ['FBI', 'CIA', 'FAA', 'Richard', 'NYPD', 'See', 'DOJ', 'DOD', 'Samuel', 'Condoleezza']
#
#
# Input Sentence: [MASK] booked a seat on a flight to Reus, near Barcelona, the next day. Atta[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Binalshibh
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: posed mounting an attack against a U.S. vessel. Bin [MASK] approved. He directed[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ladin
# Probabilities: [0.06758987 0.05807517 0.04743316 0.04061668 0.03269136 0.02709175
#  0.02509112 0.02252377 0.02247887 0.02068114]
# Top 10 Guesses: ['CIA', 'Berger', 'The', 'Clarke', 'Rice', 'CTC', 'General', 'Bin', 'Khallad', 'Binalshibh']
#
#
# Input Sentence: “Mukhtar” with Ramzi [MASK] and Moussaoui.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Binalshibh
# Probabilities: [0.14087833 0.06897984 0.05312156 0.03908329 0.03850612 0.02579959
#  0.02458    0.02114791 0.02084273 0.0200114 ]
# Top 10 Guesses: ['Bin', 'al', 'bin', 'Abu', 'Binalshibh', 'Khallad', 'Hazmi', 'Mihdhar', 'Ramzi', 'Usama']
#
#
# Input Sentence: 141. [MASK] memo, Headquarters SOC, “Planning Directive for Infinite Resolve,” Dec. 23, 1998. On basing[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: DOD
# Probabilities: [0.14916113 0.12748052 0.10175018 0.077681   0.07560781 0.06693644
#  0.06305415 0.06245425 0.05467789 0.02738442]
# Top 10 Guesses: ['CIA', 'Richard', 'FAA', 'Condoleezza', 'DOJ', 'DOD', 'NYPD', 'FBI', 'Samuel', 'William']
#
#
# Input Sentence: flew to Bangkok to meet Khallad to pass him money. See chapter 8. That was not known at the time. [MASK] was[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Mihdhar
# Probabilities: [0.10633946 0.05767599 0.05206819 0.04975421 0.04597013 0.03371431
#  0.03345471 0.03253812 0.02862802 0.02486243]
# Top 10 Guesses: ['Hazmi', 'FBI', 'Mihdhar', 'Hanjour', 'Bin', 'Jarrah', 'Khallad', 'al', 'Binalshibh', 'Abu']
#
#
# Input Sentence: also was Nashiri’s handiwork. Although [MASK] Ladin urged Nashiri to continue[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.22101165 0.10779653 0.05690262 0.05405976 0.02949254 0.01807069
#  0.0140208  0.01325404 0.01195255 0.01193959]
# Top 10 Guesses: ['the', 'CIA', 'FBI', 'al', 'Richard', 'The', 'an', 'a', 'Al', 'Hazmi']
#
#
# Input Sentence: of his ties to al [MASK] Khallad returned to Afghanistan.4>[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Qaeda
# Probabilities: [0.346331   0.07506935 0.06894699 0.01871625 0.01855486 0.01557119
#  0.01547511 0.01458088 0.01282102 0.01202676]
# Top 10 Guesses: ['Richard', 'CIA', 'The', 'FBI', 'Donald', 'Stephen', 'and', 'For', 'When', 'While']
#
#
# Input Sentence: [MASK] CTC[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: because
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: Hani [MASK][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hanjour
# Probabilities: [0.09741315 0.06981976 0.06571949 0.05639612 0.05569731 0.04337087
#  0.03408885 0.0318853  0.02845968 0.02764909]
# Top 10 Guesses: ['Ahmed', 'al', 'Hazmi', 'Hanjour', 'Ali', 'Omar', 'Saeed', 'Mihdhar', 'Sheikh', 'Abu']
#
#
# Input Sentence: No [MASK] actions seem to have been taken in response.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FAA
# Probabilities: [0.14501579 0.06758747 0.06481989 0.04535417 0.04406127 0.02959212
#  0.02811855 0.02753677 0.0244853  0.02356322]
# Top 10 Guesses: ['CIA', 'FBI', 'Richard', 'Rice', 'Berger', 'the', 'Clarke', 'and', 'Condoleezza', 'Thomas']
#
#
# Input Sentence: that he never met with Mihdhar in 1999 but assumed that [MASK] Ladin and Atef[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.15154745 0.07468011 0.05848778 0.04502456 0.0340655  0.02982787
#  0.02104993 0.0208051  0.01884924 0.0177509 ]
# Top 10 Guesses: ['Hazmi', 'CIA', 'Mihdhar', 'Hanjour', 'Jarrah', 'FBI', 'Khallad', 'the', 'Bin', 'Binalshibh']
#
#
# Input Sentence: Jarrah was supposed to be joined at FFTC [MASK] Ramzi Binalshibh, who even[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: by
# Probabilities: [0.34240058 0.04227282 0.02537495 0.01740778 0.01685138 0.01608916
#  0.01487867 0.01203506 0.00933996 0.00920287]
# Top 10 Guesses: ['by', 'while', 'Hazmi', 'Inside', 'with', 'CIA', 'for', 'Jarrah', 'and', 'NYPD']
#
#
# Input Sentence: Nevertheless, the CIA obtained a general understanding of how [MASK] Qaeda[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.67872226 0.03843533 0.03768752 0.0320708  0.01846177 0.01356832
#  0.01242736 0.00879631 0.00785994 0.00709081]
# Top 10 Guesses: ['CIA', 'FBI', 'al', 'Al', 'The', 'the', 'Richard', 'Bin', 'CTC', 'State']
#
#
# Input Sentence: The Honorable [MASK] S. Cohen, former Secretary of Defense[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: William
# Probabilities: [0.40510383 0.36840194 0.03616392 0.02843829 0.0228813  0.02032002
#  0.01446836 0.01037362 0.00886956 0.00878613]
# Top 10 Guesses: ['William', 'Thomas', 'Richard', 'Condoleezza', 'Rumsfeld', 'Samuel', 'John', 'DOD', 'Donald', 'FAA']
#
#
# Input Sentence: 2002. For his training at Pan Am International Flight Academy and completion by March 2001, see [MASK] report,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.42229652 0.14645332 0.05392932 0.05017081 0.03730487 0.02816184
#  0.02712571 0.02441671 0.01409447 0.01006735]
# Top 10 Guesses: ['FBI', 'also', 'Thomas', 'Richard', 'NYPD', 'See', 'William', 'FAA', 'CIA', 'Donald']
#
#
# Input Sentence: 32. See, e.g., [MASK] Berger interview (Jan. 14, 2004).[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Samuel
# Probabilities: [0.21158114 0.18286888 0.16271591 0.06921149 0.04352782 0.04066598
#  0.04066561 0.03913159 0.03267303 0.03242345]
# Top 10 Guesses: ['CIA', 'Richard', 'FBI', 'FAA', 'NYPD', 'DOD', 'DOJ', 'William', 'Condoleezza', 'also']
#
#
# Input Sentence: funding an overall jihad program. Rather, [MASK] Ladin selectively provided start-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.18696919 0.11478149 0.06620004 0.05876346 0.03362069 0.02507873
#  0.02077727 0.01812458 0.01687158 0.01573269]
# Top 10 Guesses: ['the', 'Bin', 'CIA', 'al', 'Clarke', 'CTC', 'Secretary', 'Hazmi', 'Richard', 'Berger']
#
#
# Input Sentence: 49. [MASK] FBI report of investigation, interview of Lee Hanson, Sept. 11, 2001.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: See
# Probabilities: [0.18299286 0.13759941 0.1338082  0.07015671 0.04730815 0.04105427
#  0.03760349 0.03416489 0.03349007 0.02021782]
# Top 10 Guesses: ['CIA', 'FBI', 'Richard', 'FAA', 'DOJ', 'Condoleezza', 'DOD', 'NYPD', 'Samuel', 'See']
#
#
# Input Sentence: 16. See NSC email, Clarke to Rice and Hadley, Possibility of an al [MASK] Attack, June 25, 2001; CIA report,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Qaeda
# Probabilities: [0.10777379 0.03821857 0.02643486 0.02530841 0.01845387 0.01436918
#  0.01418261 0.01299248 0.01216774 0.01139657]
# Top 10 Guesses: ['CIA', 'Richard', 'Qaeda', 'The', 'Donald', 'al', 'For', 'FBI', 'Against', 'See']
#
#
# Input Sentence: fowitz questioned the United States’ ability to deliver [MASK] Ladin and bring him[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.2792097  0.0764517  0.0709734  0.0294406  0.02472792 0.02014069
#  0.01933882 0.01718899 0.01584841 0.01546762]
# Top 10 Guesses: ['Bin', 'the', 'CIA', 'Hazmi', 'CTC', 'Usama', 'Moussaoui', 'Clarke', 'Mihdhar', 'suicide']
#
#
# Input Sentence: before moving to [MASK] in 1995. Mzoudi described himself as a[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hamburg
# Probabilities: [0.12641779 0.06222972 0.05758658 0.03995697 0.03573937 0.03548614
#  0.03525866 0.03206576 0.02539903 0.02232252]
# Top 10 Guesses: ['Hazmi', 'FBI', 'CIA', 'Jarrah', 'FAA', 'NYPD', 'Hanjour', 'Mihdhar', 'Abdullah', 'Shehhi']
#
#
# Input Sentence: plex, but they play out a simple theme. NORAD and the [MASK] were unpre-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FAA
# Probabilities: [0.29824334 0.11622222 0.07949705 0.05016465 0.03812372 0.02857034
#  0.02390892 0.01829142 0.01715042 0.01613764]
# Top 10 Guesses: ['CIA', 'FAA', 'NYPD', 'CTC', 'FBI', 'DOD', 'Pentagon', 'Richard', 'Bin', 'Usama']
#
#
# Input Sentence: not just Binalshibh but [MASK] rest of [MASK] Hamburg group. In 1998, Zammar[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: the
# Probabilities: [0.04995788 0.04648825 0.04219029 0.04190892 0.03567738 0.03399441
#  0.02920657 0.02908277 0.02737081 0.02241048]
# Top 10 Guesses: ['the', 'Mihdhar', 'Hazmi', 'Hanjour', 'Binalshibh', 'al', 'CIA', 'Bin', 'Jarrah', 'Abu']
#
#
# Input Sentence: tion regarding threats from [MASK] Ladin. It warned that there was an increased[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.20796444 0.15569416 0.08405498 0.03096317 0.03093449 0.0305529
#  0.02139931 0.02012102 0.01761346 0.01688333]
# Top 10 Guesses: ['Bin', 'the', 'CIA', 'CTC', 'Richard', 'al', 'Clarke', 'Usama', 'Berger', 'Hazmi']
#
#
# Input Sentence: ligence reports, interrogations of detainee, Feb. 11, 2004 (two reports). Ramzi [MASK] wired some funds with-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Binalshibh
# Probabilities: [0.11337228 0.10243822 0.04020028 0.03667552 0.03472903 0.0311136
#  0.02938787 0.02246251 0.02139262 0.01983811]
# Top 10 Guesses: ['Binalshibh', 'Khallad', 'Al', 'Bin', 'Abu', 'CIA', 'The', 'Usama', 'Berger', 'CTC']
#
#
# Input Sentence: them to a guesthouse managed [MASK] Abu Zubaydah. Days later, two men helped Hamlan cross the Pakistan-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: by
# Probabilities: [9.7302985e-01 4.2784596e-03 3.3362920e-03 2.2716031e-03 1.0563588e-03
#  9.8283438e-04 8.2404964e-04 7.5318338e-04 7.4609334e-04 5.8863562e-04]
# Top 10 Guesses: ['by', 'CIA', 'Ġby', 'FBI', 'in', 'as', 'with', 'Richard', 'By', 'at']
#
#
# Input Sentence: to Bush, “I think you will find that by far your biggest threat [MASK] Bin Ladin and[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: is
# Probabilities: [0.4378499  0.17880057 0.07950949 0.04765797 0.03014777 0.02727115
#  0.02147334 0.01832722 0.00877514 0.0071258 ]
# Top 10 Guesses: ['Bin', 'al', 'Islamist', 'suicide', 'CTC', 'Taliban', 'Usama', 'of', 'Sudan', 'Sudanese']
#
#
# Input Sentence: agents on same squads, see Larry Parkinson interview (Feb. 24, 2004); Michael Vatis interview (Jan. 21,2004); [MASK][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: DOJ
# Probabilities: [0.30264193 0.13589805 0.11273776 0.09375772 0.0587193  0.04424712
#  0.03031604 0.02799374 0.02215905 0.02171895]
# Top 10 Guesses: ['Richard', 'FBI', 'William', 'Thomas', 'Roger', 'also', 'Donald', 'CIA', 'NYPD', 'John']
#
#
# Input Sentence: recalls this exchange with the President [MASK] Clarke concerning Iraq shortly after 9/11, but did not believe the Pres-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: and
# Probabilities: [0.09957958 0.06070035 0.05601878 0.05593818 0.05209183 0.04679242
#  0.0362532  0.03585991 0.02269391 0.02011426]
# Top 10 Guesses: ['Richard', 'Secretary', 'CIA', 'Rice', 'Berger', 'and', 'Clarke', 'Rumsfeld', 'Samuel', 'William']
#
#
# Input Sentence: [MASK] report, Daily UBL/Radical Fundamentalist Threat Update, ITOS Threat Update Webpage, Aug. 1, 2001.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: the Taliban. But Clarke observed that [MASK] Ladin would probably empty his[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.09397833 0.07650319 0.07343006 0.06057335 0.05694079 0.03753888
#  0.03677847 0.03041418 0.0255773  0.02436211]
# Top 10 Guesses: ['CIA', 'Bin', 'and', 'al', 'the', 'Binalshibh', 'Hazmi', 'Mihdhar', 'Jarrah', 'Khallad']
#
#
# Input Sentence: weapon, “must be considered capable of destroying virtually any building located anywhere in the world.” [MASK][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: DOJ
# Probabilities: [0.20014922 0.11863656 0.0738959  0.05653849 0.0429978  0.03221623
#  0.02321045 0.02031501 0.01908225 0.01822176]
# Top 10 Guesses: ['Richard', 'CIA', 'FBI', 'The', 'FAA', 'NYPD', 'William', 'CTC', 'DOD', 'Clarke']
#
#
# Input Sentence: when asked what made her decide to ask [MASK] to step out of his vehicle,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ressam
# Probabilities: [0.20686457 0.14219865 0.10244834 0.04386505 0.03719005 0.02407227
#  0.02264016 0.01793049 0.01416666 0.01392569]
# Top 10 Guesses: ['CIA', 'Richard', 'FBI', 'Secretary', 'Thomas', 'the', 'Rice', 'Berger', 'William', 'ask']
#
#
# Input Sentence: for more from the [MASK] since, at the time, there was no indictment out-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Sudanese
# Probabilities: [0.21164666 0.11601075 0.08644684 0.05466082 0.03578997 0.03193371
#  0.03058376 0.02329506 0.02124768 0.01632824]
# Top 10 Guesses: ['FBI', 'CIA', 'FAA', 'Bin', 'NYPD', 'CTC', 'al', 'Pentagon', 'Hamburg', 'Taliban']
#
#
# Input Sentence: many), response to Commission letter, June 25, 2004, pp. 3-4; FBI report of investigation, interview of Fuad [MASK][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Omar
# Probabilities: [0.22320946 0.15960544 0.0356581  0.03450753 0.03247081 0.02766561
#  0.01640665 0.01529268 0.01510199 0.0146969 ]
# Top 10 Guesses: ['bin', 'Al', 'Hazmi', 'FBI', 'Ali', 'Inside', 'Ahmed', 'Khallad', 'The', 'and']
#
#
# Input Sentence: not just Binalshibh but the rest of the [MASK] group. In 1998, Zammar[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hamburg
# Probabilities: [0.12626897 0.08447282 0.07108992 0.05032579 0.03682309 0.03642074
#  0.03226674 0.02271627 0.02031158 0.01584184]
# Top 10 Guesses: ['CIA', 'Bin', 'al', 'CTC', 'FAA', 'FBI', 'Hazmi', 'Hamburg', 'Mihdhar', 'suicide']
#
#
# Input Sentence: [MASK] Bin Ladin and others.*8[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: with
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: Bin [MASK] seemed willing to include in the confederation terrorists from[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Ladin
# Probabilities: [0.8135925  0.0504371  0.02065326 0.01872543 0.01408726 0.01069654
#  0.00661321 0.00645698 0.00566802 0.00492894]
# Top 10 Guesses: ['Ladin', 'Laden', 'Binalshibh', 'left', 'and', 'Mihdhar', 'Rice', 'al', 'or', 'Omar']
#
#
# Input Sentence: [MASK] Clarke, June 24, 1999.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: and
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: After 9/11, President Bush announced that [MASK] Qaeda was responsible for the[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.08757367 0.07497124 0.0604236  0.05497638 0.04625059 0.04296435
#  0.03719773 0.03384513 0.02277491 0.01739384]
# Top 10 Guesses: ['CIA', 'Berger', 'Clarke', 'Secretary', 'the', 'Rice', 'Richard', 'Bin', 'Rumsfeld', 'CTC']
#
#
# Input Sentence: hijackings or put the adequacy of air defenses [MASK] suicide hijack-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: against
# Probabilities: [0.15680651 0.13934302 0.07337037 0.04680976 0.03214248 0.02726961
#  0.01661518 0.01497514 0.01469622 0.01394791]
# Top 10 Guesses: ['CIA', 'Richard', 'against', 'Against', 'The', 'and', 'FBI', 'nuclear', 'at', 'FAA']
#
#
# Input Sentence: That said, for completeness, we point out that in summer [MASK] CTC was[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: 2001
# Probabilities: [0.22720641 0.10080012 0.03927207 0.03219982 0.02665958 0.02400703
#  0.02334289 0.02224741 0.01586511 0.01435107]
# Top 10 Guesses: ['CIA', 'FBI', 'Al', 'the', 'The', 'Hazmi', 'Richard', '2001', 'Ali', 'FAA']
#
#
# Input Sentence: ment of Sudan seized [MASK] Bin Ladin had possessed there.®[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: everything
# Probabilities: [0.06733883 0.06680078 0.05080806 0.04358324 0.02921609 0.02335593
#  0.01867884 0.01468887 0.01432093 0.01421038]
# Top 10 Guesses: ['Bin', 'the', 'CIA', 'al', 'and', 'Mihdhar', 'Hazmi', 'Abu', 'a', 'Binalshibh']
#
#
# Input Sentence: Hanjour on the day he and [MASK] left San Diego. Ibid.; FBI electronic communication, Penttbom investigation,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hazmi
# Probabilities: [0.24216749 0.2320161  0.12871315 0.07436203 0.0339689  0.02300831
#  0.02015798 0.01701558 0.01691778 0.01661721]
# Top 10 Guesses: ['Mihdhar', 'Hanjour', 'Hazmi', 'Jarrah', 'Ahmed', 'Rice', 'Saeed', 'Shehhi', 'Nawaf', 'Yousef']
#
#
# Input Sentence: detainee says that when [MASK] Ladin returned after the general alert during July, he spoke to his confidants about[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Bin
# Probabilities: [0.09379663 0.05938203 0.05394133 0.05132955 0.04366157 0.04308657
#  0.03764984 0.03660361 0.03479784 0.03250617]
# Top 10 Guesses: ['Hazmi', 'Bin', 'Clarke', 'Binalshibh', 'Mihdhar', 'Jarrah', 'Hanjour', 'Khallad', 'Rice', 'Berger']
#
#
# Input Sentence: cooperation. The Counterterrorist Center at [MASK] for example,[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: CIA
# Probabilities: [0.66666    0.07942946 0.05872914 0.02402713 0.01359279 0.0132543
#  0.01057571 0.01009368 0.00661075 0.00449583]
# Top 10 Guesses: ['CIA', 'Richard', 'FBI', 'FAA', 'The', 'CTC', 'NYPD', 'the', 'William', 'also']
#
#
# Input Sentence: to try to clarify the situation. See [MASK] report,““American Airlines Airphone Usage,” Sept. 20, 2001; Michael Wood-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.21231173 0.1330152  0.09608734 0.08928379 0.08757935 0.06445961
#  0.04670631 0.04340894 0.03830617 0.03060744]
# Top 10 Guesses: ['FBI', 'Richard', 'FAA', 'CIA', 'NYPD', 'also', 'DOD', 'DOJ', 'William', 'Condoleezza']
#
#
# Input Sentence: 70. See trial testimony of L’Houssaine Kherchtou, United States v. [MASK] Laden, Feb. 22, 2001 (transcript pp.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: bin
# Probabilities: [0.846019   0.01065875 0.01011593 0.00980178 0.00746694 0.00650152
#  0.00593742 0.0055077  0.00498828 0.0046961 ]
# Top 10 Guesses: ['bin', 'Hazmi', 'Ahmed', 'Bin', 'FBI', 'Abu', 'Usama', 'Shehhi', 'Ramzi', 'al']
#
#
# Input Sentence: 70. For other officers’ positioning, [MASK] NYPD interview 20, Manhattan South Task Force (May 4, 2004); NYPD[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: see
# Probabilities: [9.92499530e-01 3.12053598e-03 7.75940600e-04 6.85630948e-04
#  2.06990997e-04 1.79097682e-04 1.50307082e-04 1.31076915e-04
#  1.12665337e-04 1.11948495e-04]
# Top 10 Guesses: ['see', 'See', 'and', 'the', 'NYPD', 'including', 'also', 'Richard', 'but', 'although']
#
#
# Input Sentence: The [MASK] first became concerned about terrorism as a result of hostage[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Pentagon
# Probabilities: [0.17552651 0.1737242  0.10189516 0.04646952 0.02321587 0.02289754
#  0.02016085 0.02005604 0.01999056 0.01905532]
# Top 10 Guesses: ['CIA', 'FBI', 'FAA', 'NYPD', 'Rice', 'CTC', 'DOD', 'Clarke', 'DOJ', 'Berger']
#
#
# Input Sentence: and lacking the necessary temperament. [MASK] analytic report, “Threat Threads,” Sept. 16, 2002, p. 3; Intel-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: CIA
# Probabilities: [0.2560586  0.13782494 0.10626946 0.09977053 0.04724286 0.02665873
#  0.02507708 0.0188418  0.01485911 0.01394949]
# Top 10 Guesses: ['FBI', 'Richard', 'CIA', 'The', 'See', 'Al', 'For', 'Although', 'William', 'Thomas']
#
#
# Input Sentence: the FBI had approximately 70 ongoing [MASK] Ladin-related investigations.38 No[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: bin
# Probabilities: [0.28279507 0.17592786 0.06238217 0.05715849 0.03456955 0.02986092
#  0.02949771 0.01468634 0.0136309  0.01314013]
# Top 10 Guesses: ['CIA', 'FBI', 'FAA', 'al', 'bin', 'CTC', 'NYPD', 'Bin', 'internal', 'in']
#
#
# Input Sentence: City failed to locate the hijackers, as did our own investigation. See [MASK] report, “Hijackers Timeline,” Nov. 14, 2003[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.6776134  0.04653786 0.04492645 0.03337881 0.03310861 0.02254517
#  0.01626824 0.01416291 0.01087245 0.01075808]
# Top 10 Guesses: ['FBI', 'Richard', 'also', 'CIA', 'FAA', 'NYPD', 'DOJ', 'DOD', 'Samuel', 'Condoleezza']
#
#
# Input Sentence: For the building’s physical conditions, see FDNY interview 16, [MASK] 1 (Jan. 20, 2004). For conditions in the[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Battalion
# Probabilities: [0.15727009 0.11304877 0.07995483 0.07647192 0.05054894 0.04718311
#  0.04395795 0.03979476 0.03328328 0.02195499]
# Top 10 Guesses: ['Thomas', 'Battalion', 'William', 'NYPD', 'Samuel', 'Condoleezza', 'Richard', 'DOD', 'Inside', 'FAA']
#
#
# Input Sentence: analytic report, “Couriers, Hawaladars Key to Moving Al-Qa’ida Money,” [MASK] 2003-40063CH, May 16, 2003.[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: CTC
# Probabilities: [0.0957386  0.08891618 0.08031514 0.05762183 0.05632261 0.04742401
#  0.04565716 0.02981261 0.02004589 0.01829643]
# Top 10 Guesses: ['CTC', 'Al', 'CIA', 'Bin', 'Richard', 'The', 'Usama', 'Khallad', 'Binalshibh', 'For']
#
#
# Input Sentence: 182. Condoleezza Rice meeting (Feb. 7, 2004); Donald [MASK] meeting (Jan. 30,2004); Paul Wolfowitz inter-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Rumsfeld
# Probabilities: [0.7287653  0.06651174 0.04184777 0.03786013 0.02533188 0.01771906
#  0.01235802 0.0114124  0.01036698 0.0077377 ]
# Top 10 Guesses: ['Rumsfeld', 'Condoleezza', 'Berger', 'Rice', 'Samuel', 'Donald', 'Shelton', 'Clarke', 'Cressey', 'Ashcroft']
#
#
# Input Sentence: memo, Clarke [MASK] Berger, Weekly Report, July 3, 1998; NSC email, Clarke [MASK] various NSC staff, Sept. 7, 1998; NSC[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: to
# Probabilities: [9.7729027e-01 2.1455558e-02 8.3681755e-04 1.0618678e-04 7.2803145e-05
#  4.2678279e-05 2.6104763e-05 1.3829312e-05 1.0533134e-05 7.3400288e-06]
# Top 10 Guesses: ['to', 'for', 'and', 'from', 'Ġto', 'ordered', 'that', 'with', 'of', 'Ġfor']
#
#
# Input Sentence: ject of [MASK] counterterrorism investigations. The investigations did not yield evidence of criminal conduct. Thu-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: FBI
# Probabilities: [0.13674496 0.13266453 0.06674632 0.04014594 0.03025259 0.02185493
#  0.02133746 0.02044688 0.01921172 0.018328  ]
# Top 10 Guesses: ['FBI', 'CIA', 'the', 'FAA', 'Richard', 'Rice', 'Samuel', 'NYPD', 'Berger', 'DOJ']
#
#
# Input Sentence: just a guess but a link to someone known to be an al [MASK] operative. !29[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Qaeda
# Probabilities: [0.25668633 0.11838708 0.0508647  0.03254524 0.02125559 0.01467126
#  0.01461388 0.01442011 0.01260669 0.01176484]
# Top 10 Guesses: ['Richard', 'CIA', 'FBI', 'The', 'Donald', 'Stephen', 'See', 'For', 'When', 'Although']
#
#
# Input Sentence: [MASK] arrived in Kuala Lumpur soon thereafter and may even have stayed[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Hazmi
# Probabilities: [0.1596688  0.05893537 0.05609728 0.03945578 0.03014345 0.02891391
#  0.02623602 0.02494727 0.01902921 0.01814801]
# Top 10 Guesses: ['FBI', 'and', 'CIA', 'Richard', 'FAA', 'al', 'Al', 'Ali', 'Binalshibh', 'bin']
#
#
# Input Sentence: head of the media committee, he would take charge of producing the propaganda video [MASK] Qaeda issued follow-[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: al
# Probabilities: [0.06056437 0.0503527  0.04866721 0.04091341 0.03355357 0.03068639
#  0.03053154 0.02846384 0.02509171 0.02492387]
# Top 10 Guesses: ['Bin', 'Hazmi', 'Binalshibh', 'Khallad', 'Omar', 'Jarrah', 'Abu', 'Mihdhar', 'Berger', 'Hanjour']
#
#
# Input Sentence: mary re Jarrah, July 18,2002, p.60. According to [MASK] Senguen visited Jarrah in order to verify that he actually[PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]
# Correct Label: Binalshibh
# Probabilities: [0.1620553  0.09781346 0.09640244 0.05103824 0.03674615 0.03002487
#  0.02756877 0.02543072 0.0235112  0.02172275]
# Top 10 Guesses: ['Berger', 'Binalshibh', 'Rice', 'Clarke', 'Khallad', 'Hadley', 'Jarrah', 'Hanjour', 'Hazmi', 'Ahmed']
